# %%
fullname= 'swarna rekha'
print (fullname)
# Out:
# swarna rekha

# %%
print (fullname.upper())
# Out:
# SWARNA REKHA

# %%
print (fullname.lower())
# Out:
# swarna rekha

# %%
print (fullname.title())
# Out:
# Swarna Rekha

# %%
## adding whitespaces to the string:

# %%
print ('fav_programming:\nPython\nC\njava\nC++\nSwift\nCobol')
# Out:
# fav_programming:
# Python
# C
# java
# C++
# Swift
# Cobol

# %%
print ('fav_programming:\n\tPython\n\tC\n\tjava\n\tC++\n\tSwift\n\tCobol')
# Out:
# fav_programming:
# 	Python
# 	C
# 	java
# 	C++
# 	Swift
# 	Cobol
